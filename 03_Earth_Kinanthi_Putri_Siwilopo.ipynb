# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Rietaros/kampus_merdeka/main/HRDataset_v14.csv')
data.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 0            1       5            4                       0   62506      0
# 1            5       3            3                       0  104437      1
# 2            5       5            3                       0   64955      1
# 3            1       5            3                       0   64991      0
# 4            5       5            3                       0   50825      1
#
#    PositionID                  Position State   Zip       DOB Sex MaritalDesc  \
# 0          19   Production Technician I    MA  1960  07/10/83  M       Single
# 1          27                   Sr. DBA    MA  2148  05/05/75  M      Married
# 2          20  Production Technician II    MA  1810  09/19/88   F     Married
# 3          19   Production Technician I    MA  1886  09/27/88   F     Married
# 4          19   Production Technician I    MA  2169  09/08/89   F    Divorced
#
#   CitizenDesc HispanicLatino RaceDesc DateofHire DateofTermination  \
# 0  US Citizen             No    White   7/5/2011               NaN
# 1  US Citizen             No    White  3/30/2015         6/16/2016
# 2  US Citizen             No    White   7/5/2011         9/24/2012
# 3  US Citizen             No    White   1/7/2008               NaN
# 4  US Citizen             No    White  7/11/2011          9/6/2016
#
#           TermReason        EmploymentStatus         Department  \
# 0  N/A-StillEmployed                  Active  Production
# 1      career change  Voluntarily Terminated              IT/IS
# 2              hours  Voluntarily Terminated  Production
# 3  N/A-StillEmployed                  Active  Production
# 4   return to school  Voluntarily Terminated  Production
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
# 4  Webster Butler       39.0     Google Search      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# 0              4.60                5                     0
# 1              4.96                3                     6
# 2              3.02                3                     0
# 3              4.84                5                     0
# 4              5.00                4                     0
#
#   LastPerformanceReview_Date  DaysLateLast30  Absences
# 0                  1/17/2019               0         1
# 1                  2/24/2016               0        17
# 2                  5/15/2012               0         3
# 3                   1/3/2019               0        15
# 4                   2/1/2016               0         2

# %% [markdown]
# # Pandas Question

# %% [markdown]
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender.
# Hints: use agg function<br>
# Expected Output as below<br>
# (5 Points)

# %%
# 1. What is the minimum, median, max, and average salary for employee by Married Description and Gender
# Hints: use agg function
# Expected Output as below
# (5 Points)

data.groupby(['MaritalDesc', 'Sex']) \
  .agg(min_salary = ('Salary','min'), median_salary = ('Salary', 'median'), max_salary = ('Salary', 'max'), average_salary = ('Salary','mean'))
# Out:
#                  min_salary  median_salary  max_salary  average_salary
# MaritalDesc Sex
# Divorced    F         45069        59393.0       68182    57345.500000
#             M         45115        63738.5      148999    72520.857143
# Married     F         45433        62662.0      250000    69638.986111
#             M         46120        63370.5      157000    70089.038462
# Separated   F         52984        60627.0       66149    60658.888889
#             M         64397        70468.0       74417    69760.666667
# Single      F         45395        62068.0      220450    68988.266667
#             M         46428        63055.5      178000    71340.048387
# Widowed     F         45046        63303.5      107226    69719.750000
#             M         52788        61359.0       67176    60670.500000

# %% [markdown]
# 2. What is top-5 reason of termination?<br>
# Expected Output as below<br>
# (5 Points)

# %%
#code here
import pandas as pd

data.groupby(['TermReason']) \
  .agg(total_termination=('TermReason','count')) \
  .sort_values(by='total_termination', ascending=False) \
  .head()
# Out:
#                    total_termination
# TermReason
# N/A-StillEmployed                207
# Another position                  20
# unhappy                           14
# more money                        11
# career change                      9

# %% [markdown]
# 3. What is the highest number of employee by Recruitment Source that 'Exceeds' the Performance Score?
# Hints: Use filter for Performance Score first. Don't forget to sort_values.<br>
# Expected Output as below<br>
# (5 Points)

# %%
#code here

data.loc[data['PerformanceScore'] == 'Exceeds'] \
           .groupby(['RecruitmentSource']) \
           .agg(Total_Recruit=('RecruitmentSource', 'count')) \
           .sort_values(by='Total_Recruit', ascending=False)
# Out:
#                     Total_Recruit
# RecruitmentSource
# Indeed                         12
# LinkedIn                        9
# Diversity Job Fair              6
# Employee Referral               5
# CareerBuilder                   2
# Google Search                   2
# Website                         1

# %% [markdown]
# 4. How many managers in each department?
# Hints: use nunique() as aggregation function.<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#code here

data.groupby('Department')['ManagerName'].nunique().to_frame()
# Out:
#                       ManagerName
# Department
# Admin Offices                   3
# Executive Office                1
# IT/IS                           6
# Production                     10
# Sales                           4
# Software Engineering            3

# %% [markdown]
# 5. What is Termination Ratio by Gender?.
# Hints: use value_counts(normalize=True).<br>
# Expected Output as below.<br>
# (5 Points)

# %%
#code here

data.groupby('Sex')['Termd'].value_counts(normalize=True)
# Out:
# Sex  Termd
# F    0        0.659091
#      1        0.340909
# M    0        0.674074
#      1        0.325926
# Name: Termd, dtype: float64

# %% [markdown]
# # Create an EDA and Data Visualization Question

# %%
#Sample Visualization, the example is not counted for the final score :p
#Create 5 visualization for better understanding on data
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

#Ratio termination by Gender

#Step1, get the data

term = data.groupby(by=['Sex'])\
                        .agg(total_termination=('Termd','sum')).reset_index()\

#Step2, Plot it
f, ax = plt.subplots(1, 1, figsize=(12, 8))
ax = sns.barplot(x='Sex', y='total_termination', hue='Sex', data=term, palette='cool')

# %% [markdown]
# 6. Buatlah Scatter plot antara kolom "Salary" dengan "EngagementSurvey", beri warna berbeda sesuai dengan status di "Termd"<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
#code here

sns.scatterplot(data=data, x="Salary", y="EngagementSurvey", hue="Termd", palette="cool")
plt.title('Scatter Plot: Salary vs. EngagementSurvey by Termination Status')

plt.show()

# %% [markdown]
# 7. Buatlah visualisasi barchart untuk menghitung jumlah "termination of an employee's" berdasarkan department.<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=data[data['Termd'] == 1], x='Department', palette='Set2')

#dept_counts = data["Department"].value_counts()

plt.xlabel('Departement')
plt.ylabel('Termd')
plt.title('Number of Terminations by Department')

#plt.xticks(rotation=45, ha='right')

#plt.tight_layout()
plt.show()

# %% [markdown]
# 8. Buatlah visualisasi Pie Chart untuk melihat persentasi jumlah karyawan yang "terminated" berdasarkan kolom "Position".<br>
# (5 points)<br>
# *bentuk output di bawah hanya contoh*

# %%
terminated_df = data[data['Termd'] == 1]
termination_counts = terminated_df['Position'].value_counts()

plt.figure(figsize=(10, 6))
plt.pie(termination_counts, labels=termination_counts.index, autopct='%1.1f%%', startangle=140)

plt.axis('equal')

plt.title('Percentage of Terminated Employees by Position')

plt.show()

# %% [markdown]
# 9. Buat Boxplot yang menggambarkan Salary berdasarkan Marital Desc, bedakan berdasarkan Termd
# (5 points)

# %%
#code here

plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Salary', y='MaritalDesc', hue='Termd', palette='Set2')

plt.xlabel('Salary')
plt.ylabel('MaritalDesc')
plt.title('Boxplot Salary based on Marital Desc (Termd = Terminated)')

plt.xticks(rotation=30, ha='right')

plt.show()

# %% [markdown]
# 10. Tampilkan pairplot antara kolom 'Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences'
# beri kategori warna berdasarkan 'Termd'<br>
# (5points)

# %%
#codde here
print('Pairplot')
sns.pairplot(data=data[['Salary', 'EngagementSurvey', 'EmpSatisfaction','Absences', 'Termd']], hue='Termd', height=3, diag_kind="hist")
plt.show()
# Out:
# Pairplot

# %% [markdown]
# # Create Machine Learning Model to Predict Termd and Question

# %%
#11. Buat fitur baru (kolom baru) berupa "Age" dalam satuan tahun. Untuk mendapatkannya, ambil data pada kolom DOB dikurangi dengan 2022
#(5 points)

data['DOB_date'] = pd.to_datetime(data['DOB'], format='%m/%d/%y')
Year = pd.to_datetime('2022').year
data['Age'] = Year - data['DOB_date'].dt.year

data[['DOB', 'DOB_date', 'Age']]
# Out:
#           DOB   DOB_date  Age
# 0    07/10/83 1983-07-10   39
# 1    05/05/75 1975-05-05   47
# 2    09/19/88 1988-09-19   34
# 3    09/27/88 1988-09-27   34
# 4    09/08/89 1989-09-08   33
# ..        ...        ...  ...
# 306  05/11/85 1985-05-11   37
# 307  05/04/82 1982-05-04   40
# 308  08/30/79 1979-08-30   43
# 309  02/24/79 1979-02-24   43
# 310  08/17/78 1978-08-17   44
#
# [311 rows x 3 columns]

# %%
#12. Lakukan MinMaxScaler dari fitur "Salary"
# (5 points)
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
data['Salary_minmax'] = scaler.fit_transform(data[['Salary']])

data[['Salary', 'Salary_minmax']]
# Out:
#      Salary  Salary_minmax
# 0     62506       0.085190
# 1    104437       0.289777
# 2     64955       0.097139
# 3     64991       0.097315
# 4     50825       0.028197
# ..      ...            ...
# 306   65893       0.101716
# 307   48513       0.016916
# 308  220450       0.855821
# 309   89292       0.215883
# 310   45046       0.000000
#
# [311 rows x 2 columns]

# %%
#13. Ubahlah semua tipe data object menjadi category
# 5 point

data.dtypes
# Out:
# Employee_Name                         object
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                              object
# State                                 object
# Zip                                    int64
# DOB                                   object
# Sex                                   object
# MaritalDesc                           object
# CitizenDesc                           object
# HispanicLatino                        object
# RaceDesc                              object
# DateofHire                            object
# DateofTermination                     object
# TermReason                            object
# EmploymentStatus                      object
# Department                            object
# ManagerName                           object
# ManagerID                            float64
# RecruitmentSource                     object
# PerformanceScore                      object
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date            object
# DaysLateLast30                         int64
# Absences                               int64
# Age                                    int64
# DOB_date                      datetime64[ns]
# Salary_minmax                        float64
# dtype: object

# %%
#Setelah diubah category

object_cols = data.select_dtypes(include=["object"]).columns.tolist()
data[object_cols] = data[object_cols].astype("category")

data.dtypes
# Out:
# Employee_Name                       category
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                            category
# State                               category
# Zip                                    int64
# DOB                                 category
# Sex                                 category
# MaritalDesc                         category
# CitizenDesc                         category
# HispanicLatino                      category
# RaceDesc                            category
# DateofHire                          category
# DateofTermination                   category
# TermReason                          category
# EmploymentStatus                    category
# Department                          category
# ManagerName                         category
# ManagerID                            float64
# RecruitmentSource                   category
# PerformanceScore                    category
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date          category
# DaysLateLast30                         int64
# Absences                               int64
# Age                                    int64
# DOB_date                      datetime64[ns]
# Salary_minmax                        float64
# dtype: object

# %%
#14. Ubahlah "RecruitmentSource" dengan menggunakana Label Encoder
# 5 point

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['RecruitmentSource'] = label_encoder.fit_transform(data['RecruitmentSource'])

#15. Ubahlah "PerformanceScore" dengan menggunakana Label Encoder
# 5 point

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['PerformanceScore'] = label_encoder.fit_transform(data['PerformanceScore'])

data.dtypes
# Out:
# Employee_Name                       category
# EmpID                                  int64
# MarriedID                              int64
# MaritalStatusID                        int64
# GenderID                               int64
# EmpStatusID                            int64
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                 int64
# Salary                                 int64
# Termd                                  int64
# PositionID                             int64
# Position                            category
# State                               category
# Zip                                    int64
# DOB                                 category
# Sex                                 category
# MaritalDesc                         category
# CitizenDesc                         category
# HispanicLatino                      category
# RaceDesc                            category
# DateofHire                          category
# DateofTermination                   category
# TermReason                          category
# EmploymentStatus                    category
# Department                          category
# ManagerName                         category
# ManagerID                            float64
# RecruitmentSource                      int64
# PerformanceScore                       int64
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date          category
# DaysLateLast30                         int64
# Absences                               int64
# Age                                    int64
# DOB_date                      datetime64[ns]
# Salary_minmax                        float64
# dtype: object

# %%
#16. Pisahkan dependent variable dan independent variable
# 5 point

#Dependent Varible (target)
y = data['Termd']

#Independent Variable (feature) x
x = data[['MarriedID', 'MaritalStatusID',
                 'GenderID', 'DeptID',
                 'PerfScoreID', 'PositionID',
                 'Age', 'RecruitmentSource',
                 'PerformanceScore', 'Salary_minmax',
                 'Absences', 'SpecialProjectsCount',
                 'EmpSatisfaction','EngagementSurvey']]

x.head()
# Out:
#    MarriedID  MaritalStatusID  GenderID  DeptID  PerfScoreID  PositionID  Age  \
# 0          0                0         1       5            4          19   39
# 1          1                1         1       3            3          27   47
# 2          1                1         0       5            3          20   34
# 3          1                1         0       5            3          19   34
# 4          0                2         0       5            3          19   33
#
#    RecruitmentSource  PerformanceScore  Salary_minmax  Absences  \
# 0                  5                 0       0.085190         1
# 1                  4                 1       0.289777        17
# 2                  5                 1       0.097139         3
# 3                  4                 1       0.097315        15
# 4                  3                 1       0.028197         2
#
#    SpecialProjectsCount  EmpSatisfaction  EngagementSurvey
# 0                     0                5              4.60
# 1                     6                3              4.96
# 2                     0                3              3.02
# 3                     0                5              4.84
# 4                     0                4              5.00

# %%
#17. Bagi data menjadi Train-Test sebesar 80:20
# (5 points)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_curve, roc_curve, precision_score, recall_score

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
#18. Lakukan pemodelan machine learning (metode klasifikasi bebas) untuk bisa memprediksi status "Termd". Lakukan evaluasi hasil dengan menampilkan
# score klasifikasi, precision dan recall.
# Gunakan model yang menurut kalian terbaik
# (5 points)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression(tol=0.00001, C=1, max_iter=1000, penalty = 'none')

train_model = model.fit(x_train, y_train)

# make predictions for test data
y_pred = train_model.predict(x_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
precision = precision_score(y_test, predictions)
recall = recall_score(y_test, predictions)
print("Accuracy  %.2f%%" % (accuracy * 100.0))
print("Precision : %.2f%%" % (precision* 100.0))
print("Recall : %.2f%%" % (recall * 100.0))
# Out:
# Accuracy  66.67%
# Precision : 53.85%
# Recall : 31.82%
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1173: FutureWarning: `penalty='none'`has been deprecated in 1.2 and will be removed in 1.4. To keep the past behaviour, set `penalty=None`.
#   warnings.warn(

# %% [markdown]
# # Insight (Answering the Question)
#
# 19.	Is there any relationship between who a person works for (their manager) and their performance score? (5 points)<br>
# 20.	What are our best recruiting sources if we want to ensure a low ratio of termination? (5 points)<br>

# %% [markdown]
# 19. Berdasarkan data di bawah, memang terdapat hubungan antara manajer dan performance score seorang karyawan, namun tidak selalu berarti bahwa performance score seorang karyawan bergantung secara signifikan pada siapa manajernya. Dalam data tersebut, terlihat bahwa meskipun beberapa karyawan memiliki manajer yang sama, performance score mereka masih bervariasi.

# %%
cols_to_display = ['ManagerName', 'Employee_Name', 'PerformanceScore', 'TermReason']
new_df = data[cols_to_display]

print(new_df.to_string(index=False))
# Out:
#        ManagerName             Employee_Name  PerformanceScore                       TermReason
#     Michael Albert       Adinolfi, Wilson  K                 0                N/A-StillEmployed
#         Simon Roup  Ait Sidi, Karthikeyan                    1                    career change
#     Kissy Sullivan         Akinkuolie, Sarah                 1                            hours
#       Elijiah Gray              Alagbe,Trina                 1                N/A-StillEmployed
#     Webster Butler          Anderson, Carol                  1                 return to school
#           Amy Dunn         Anderson, Linda                   0                N/A-StillEmployed
#    Alex Sweetwater           Andreola, Colby                 1                N/A-StillEmployed
#      Ketsia Liebig               Athwal, Sam                 1                N/A-StillEmployed
#     Brannon Miller          Bachiochi, Linda                 1                N/A-StillEmployed
#       Peter Monroe        Bacong, Alejandro                  1                N/A-StillEmployed
#      David Stanley      Baczenski, Rachael                   1                 Another position
#     Kissy Sullivan           Barbara, Thomas                 1                          unhappy
#         Simon Roup          Barbossa, Hector                 0                N/A-StillEmployed
#      Kelley Spirea      Barone, Francesco  A                 1                N/A-StillEmployed
#     Michael Albert             Barton, Nader                 1                 Another position
#      Kelley Spirea             Bates, Norman                 1                       attendance
#      Kelley Spirea          Beak, Kimberly                   0                N/A-StillEmployed
#       Elijiah Gray       Beatrice, Courtney                  1                N/A-StillEmployed
#         Simon Roup             Becker, Renee                 1                      performance
#     Webster Butler             Becker, Scott                 1                N/A-StillEmployed
#           Amy Dunn           Bernstein, Sean                 1                N/A-StillEmployed
#      Ketsia Liebig           Biden, Lowan  M                 1                N/A-StillEmployed
#     Brannon Miller             Billis, Helen                 0                N/A-StillEmployed
#     Michael Albert            Blount, Dianna                 2                N/A-StillEmployed
#       Elijiah Gray           Bondwell, Betsy                 1                    career change
#         Simon Roup              Booth, Frank                 1    Learned that he is a gangster
#     Brannon Miller                Pham, Hong                 1                       more money
#      David Stanley               Pitt, Brad                  1                N/A-StillEmployed
#      Lynn Daneault               Potts, Xana                 1                N/A-StillEmployed
#     Kissy Sullivan            Power, Morissa                 1                 Another position
#      Kelley Spirea         Punjabhi, Louis                   1                N/A-StillEmployed
#     Kissy Sullivan          Purinton, Janine                 1                          unhappy
#         Janet King               Quinn, Sean                 1                    career change
#   Brian Champaigne           Rachael, Maggie                 1                N/A-StillEmployed
#     Michael Albert            Rarrick, Quinn                 1                       more money
#         John Smith                 Ren, Kylo                 1                N/A-StillEmployed
#       Elijiah Gray            Rhoads, Thomas                 1                         retiring
#     Webster Butler           Rivera, Haley                   0                N/A-StillEmployed
#      David Stanley             Roberson, May                 1                 return to school
#     Kissy Sullivan          Robertson, Peter                 1                 Another position
#           Amy Dunn         Robinson, Alain                   1                       attendance
#      Ketsia Liebig          Robinson, Cherly                 2                       attendance
#     Brannon Miller           Robinson, Elias                 0                N/A-StillEmployed
#         Simon Roup               Roby, Lori                  1                N/A-StillEmployed
#         Simon Roup          Roehrich, Bianca                 1                 Another position
#   Brian Champaigne              Roper, Katie                 1                N/A-StillEmployed
#      David Stanley            Rose, Ashley                   1                N/A-StillEmployed
#     Kissy Sullivan           Rossetti, Bruno                 1                 Another position
#    Jennifer Zamora                Roup,Simon                 1                N/A-StillEmployed
#    Jennifer Zamora             Ruiz, Ricardo                 1                            hours
#    Alex Sweetwater              Saada, Adell                 1                N/A-StillEmployed
#      Kelley Spirea     Saar-Beckles, Melinda                 2                N/A-StillEmployed
#     Michael Albert             Sadki, Nore                   1           relocation out of area
#      Kelley Spirea               Sahoo, Adil                 1                N/A-StillEmployed
#         Simon Roup             Salter, Jason                 1                            hours
#       Elijiah Gray            Sander, Kamrin                 1                N/A-StillEmployed
#     Webster Butler            Sewkumar, Nori                 1                N/A-StillEmployed
#       Peter Monroe           Shepard, Anita                  1                N/A-StillEmployed
#           Amy Dunn            Shields, Seffi                 1                N/A-StillEmployed
#         Simon Roup            Simard, Kramer                 1                N/A-StillEmployed
# Brandon R. LeBlanc               Singh, Nan                  1                N/A-StillEmployed
#     Michael Albert          Sloan, Constance                 1 maternity leave - did not return
#       Elijiah Gray                Smith, Joe                 0                N/A-StillEmployed
#     Debra Houlihan               Smith, John                 2                N/A-StillEmployed
# Brandon R. LeBlanc          Smith, Leigh Ann                 1                    career change
#      Ketsia Liebig               Smith, Sade                 1                N/A-StillEmployed
#       Eric Dougall              Soto, Julia                  1                N/A-StillEmployed
#       Peter Monroe              Soze, Keyser                 1                N/A-StillEmployed
#     Brannon Miller          Sparks, Taylor                   3                N/A-StillEmployed
#         Janet King            Spirea, Kelley                 1                N/A-StillEmployed
#      David Stanley        Squatrito, Kristen                 0                          unhappy
#     Kissy Sullivan       Stanford,Barbara  M                 1                N/A-StillEmployed
#      Lynn Daneault        Stansfield, Norman                 3                N/A-StillEmployed
# Brandon R. LeBlanc          Steans, Tyrone                   1                N/A-StillEmployed
#      Kelley Spirea              Stoica, Rick                 1                N/A-StillEmployed
#         John Smith           Strong, Caitrin                 1                N/A-StillEmployed
#         Janet King          Sullivan, Kissy                  1                N/A-StillEmployed
#     Michael Albert         Sullivan, Timothy                 1                N/A-StillEmployed
#       Elijiah Gray          Sutwell, Barbara                 1                N/A-StillEmployed
#    Alex Sweetwater             Szabo, Andrew                 0                N/A-StillEmployed
#   Brian Champaigne              Tannen, Biff                 1                N/A-StillEmployed
#     Webster Butler        Tavares, Desiree                   1                 Another position
#       Elijiah Gray           Tejeda, Lenora                  1                 Another position
#      Lynn Daneault          Terry, Sharlene                  1                N/A-StillEmployed
#           Amy Dunn        Theamstern, Sophia                 1                 return to school
#     Webster Butler          Thibaud, Kenneth                 1                         military
#     Brannon Miller         Tippett, Jeanette                 1                N/A-StillEmployed
#      Lynn Daneault            Torrence, Jack                 0                N/A-StillEmployed
#      David Stanley                Trang, Mei                 2                N/A-StillEmployed
#       Peter Monroe      Tredinnick, Neville                  1                   medical issues
#    Alex Sweetwater              True, Edward                 1                   medical issues
#           Amy Dunn           Trzeciak, Cybil                 1                          unhappy
#       Peter Monroe             Turpin, Jumil                 1                N/A-StillEmployed
#         John Smith           Valentin,Jackie                 1                N/A-StillEmployed
#     Kissy Sullivan          Veera, Abdellah                  0 maternity leave - did not return
#         Janet King             Vega, Vincent                 1                N/A-StillEmployed
#         John Smith          Villanueva, Noah                 1                N/A-StillEmployed
#         Simon Roup           Voldemort, Lord                 1                 no-call, no-show
#      Kelley Spirea             Volk, Colleen                 0                 gross misconduct
#     Michael Albert      Von Massenbach, Anna                 1                N/A-StillEmployed
#      Ketsia Liebig             Walker, Roger                 1                N/A-StillEmployed
#         Janet King      Wallace, Courtney  E                 1                 Another position
#       Elijiah Gray          Wallace, Theresa                 2                    career change
#   Brian Champaigne             Wang, Charlie                 1                N/A-StillEmployed
#       Peter Monroe           Warfield, Sarah                 1                N/A-StillEmployed
#     Webster Butler           Whittier, Scott                 1                            hours
#           Amy Dunn             Wilber, Barry                 1                          unhappy
#      Ketsia Liebig             Wilkes, Annie                 1                 Another position
#      Ketsia Liebig     Williams, Jacquelyn                   1           relocation out of area
#     Brannon Miller        Winthrop, Jordan                   0                         retiring
#      David Stanley             Wolk, Hang  T                 1                N/A-StillEmployed
#     Kissy Sullivan            Woodson, Jason                 1                N/A-StillEmployed
#     Brannon Miller        Ybarra, Catherine                  3                 Another position
#         Janet King          Zamora, Jennifer                 0                N/A-StillEmployed
#         Simon Roup               Zhou, Julia                 1                N/A-StillEmployed
#      David Stanley             Zima, Colleen                 1                N/A-StillEmployed

# %% [markdown]
# 20. Berdasarkan barplot di bawah, dapat disimpulkan bahwa sumber perekrutan terbaik adalah On-Line Web Application, Website, dan Other, karena ketiganya memiliki jumlah terminasi yang paling sedikit, yaitu kurang dari 5.

# %%
df_termd = data[data["Termd"] == 1]

dept_counts = df_termd["RecruitmentSource"].value_counts()

plt.figure(figsize=(10,6))
sns.barplot(x=dept_counts.values, y=dept_counts.index, palette="cool")

plt.title("Number of Terminations by Recruitment Source")
plt.xlabel("Termd")
plt.ylabel("RecruitmentSource")

plt.show()
